# %%
pip install opencv-python

# %%
import cv2

# %%
img=cv2.imread("/content/123.jpg")

# %%
print(img)
# Out:
# [[[ 3  0  2]
#   [11  8 10]
#   [23 18 20]
#   ...
#   [ 7  8  4]
#   [ 2  0  0]
#   [17 13 12]]
#
#  [[ 2  0  1]
#   [10  7  9]
#   [16 11 13]
#   ...
#   [13 17 12]
#   [ 2  0  0]
#   [13  9  8]]
#
#  [[14 11 13]
#   [ 9  6  8]
#   [ 2  0  0]
#   ...
#   [ 2  6  1]
#   [ 2  0  0]
#   [10  8  7]]
#
#  ...
#
#  [[ 8 10 10]
#   [ 5  7  7]
#   [ 0  2  1]
#   ...
#   [ 0  0  1]
#   [ 9  4  6]
#   [ 7  0  3]]
#
#  [[ 2  4  4]
#   [ 0  2  2]
#   [ 0  1  0]
#   ...
#   [ 0  0  1]
#   [ 9  4  6]
#   [ 7  0  3]]
#
#  [[ 1  3  3]
#   [ 0  0  0]
#   [ 0  1  0]
#   ...
#   [ 0  0  1]
#   [ 9  4  6]
#   [ 7  0  3]]]

# %%
img.shape
# Out:
# (939, 742, 3)

# %%
img[0]
# Out:
# array([[ 3,  0,  2],
#        [11,  8, 10],
#        [23, 18, 20],
#        ...,
#        [ 7,  8,  4],
#        [ 2,  0,  0],
#        [17, 13, 12]], dtype=uint8)

# %%
img[0][0]
# Out:
# array([3, 0, 2], dtype=uint8)

# %% [markdown]
# we can see image using
#
# * cv2.imshow('img',img)
# *   cv2.waitKey(0)
# *  cv2.destroyallwindow()

# %%
from matplotlib import pyplot as plt

# %%
plt.imshow(img)

# %%
image = cv2.imread(p)

# %%
image=cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)

# %%
plt.imshow(image)
